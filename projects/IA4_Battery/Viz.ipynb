# %%
import matplotlib.pyplot as plt

from process import Data
import seaborn as sns

camino1 = r"C:\Users\Elfamoso\OneDrive\Bureau\Veille\Portfolio\IA4Battery\eCO2mix_RTE_Annuel-Definitif_2023\df_2023.csv"
camino2 = r"C:\Users\Elfamoso\OneDrive\Bureau\Veille\Portfolio\IA4Battery\eCO2mix_RTE_Annuel-Definitif_2024\df_2024.csv"

# %%
data = Data(camino1, camino2)

# %%
df = data.conso

# %%
df = df.drop(columns=["Prévision J"])

# %%
print(df.columns)
# Out:
# Index(['Consommation', 'Prévision J-1'], dtype='str')

# %%
for col in df.columns:
    df[col] = df[col].rolling(window=4, center=True).mean()
df = df.ffill().interpolate(method="time").bfill()

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
# --> 168 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
# --> 197 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7668 'Could not get source, probably due dynamically evaluated source code.'
#
# ...
