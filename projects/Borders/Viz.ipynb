# %%
import Optimizer
from Process import P0
from Optimizer import Apollon

# %%
arrivals_df = (
    r"C:\Users\Elfamoso\OneDrive\Bureau\Veille\Portfolio\Customs\Arrivals_HD.xlsx"
)
average_df = (
    r"C:\Users\Elfamoso\OneDrive\Bureau\Veille\Portfolio\Customs\Average_time.xlsx"
)

# %%
data = P0(arrivals_df, average_df).data

# %%
obj = Apollon(data, 30)
# Out:
# ### === nombre de douaniers : 49.0 === ###

# %%
# Exemple d'appel pour comparer les 3 méthodes
Tau = 60.0  # Ton paramètre cible
obj.sol_SHGO(Tau)
